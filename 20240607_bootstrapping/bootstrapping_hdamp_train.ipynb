# %%
from __future__ import absolute_import, division, print_function
from tensorflow.keras.layers import Lambda, Dense, Input, Layer, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, LambdaCallback
from tensorflow.keras.initializers import Constant
from tensorflow.keras.backend import concatenate
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K


import gc
import argparse

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in tf.config.list_physical_devices("GPU"):
    tf.config.experimental.set_memory_growth(gpu, True)
tf.config.set_visible_devices(gpus[0], 'GPU')

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
# 2024-06-12 09:04:34.494886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:04:34.510641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:04:34.510910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
# standard numerical library imports
import numpy as np
import math
from math import *
import scipy as sp
import matplotlib.pyplot as plt
import os

# energyflow imports
import energyflow as ef
from energyflow.archs import PFN
from energyflow.utils import data_split, to_categorical

# %%
# Global plot settings
from matplotlib import rc
import matplotlib.font_manager
rc('font', family='serif')
rc('text', usetex=False)
rc('font', size=22)
rc('xtick', labelsize=15)
rc('ytick', labelsize=15)
rc('legend', fontsize=15)


pythia_text = r'$POWHEG \; (hvq) \; pp \to  t\bar{t}$'
def make_legend(ax, title):
    leg = ax.legend(frameon=False)
    leg.set_title(title, prop={'size':20})
    leg.texts[0].set_fontsize(20)
    leg._legend_box.align = "left"
    plt.tight_layout()


import mplhep as hep
plt.style.use(hep.style.CMS)

# %%
# define training iter function and helpful setup_nn function

def setup_nn(Phi_sizes = (100,100,128), F_sizes = (100,100,100), input_dim=6, patience = 15, save_label = 'DCTR_training', out_dir = './saved_models'):

    dctr = PFN(input_dim = input_dim,
               Phi_sizes = Phi_sizes, 
               F_sizes   = F_sizes,
               summary   = False)

    os.makedirs(os.path.dirname(f'{out_dir}/{save_label}.h5'), exist_ok=True) # create output dir, if it doesn't exist
    
    checkpoint = keras.callbacks.ModelCheckpoint(f'{out_dir}/{save_label}.h5',
                                                    monitor='val_loss',
                                                    verbose=2,
                                                    save_best_only=True,
                                                    mode='min')
    
    CSVLogger = keras.callbacks.CSVLogger(f'{out_dir}/{save_label}_loss.csv', append=False)
    
    EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  min_delta=0,
                                                  patience=patience,
                                                  verbose=1,
                                                  restore_best_weights=True)
    
    callbacks = [checkpoint, CSVLogger, EarlyStopping]

    return dctr, callbacks


def train_single_iteration(X0, X1, iteration, num_events = int(4e7), batch_size = (5*8192), save_label = 'DCTR_training', out_dir = './saved_models'):
    # take random num_evts from each dataset
    rand0 = np.random.choice(len(X0), num_events) # num_evts random indices
    rand1 = np.random.choice(len(X1), num_events)

    local_X0 = X0[rand0]
    local_X1 = X1[rand1]

    # create classifier array Y
    Y0 = np.array([0. for i in range(local_X0.shape[0])])
    Y1 = np.array([1. for i in range(local_X1.shape[0])])

    Y = np.concatenate((Y0, Y1))
    Y = to_categorical(Y, num_classes=2)

    # create training array
    X = []
    X = np.concatenate((local_X0, local_X1))
    
    X_train, X_val, Y_train, Y_val = data_split(X, Y, test=0.25, shuffle=True)

    del rand0, rand1, local_X0, local_X1, X, Y # delete the tmp variables to free memory
    gc.collect() # collect garbage to free memory

    # ready to start training
    dctr, callbacks = setup_nn(save_label = f'{save_label}_iter_{iteration:02d}', out_dir = out_dir)

    print('Starting training')
    history = dctr.fit(X_train, Y_train,
                       epochs = 1000,
                       batch_size = batch_size,
                       validation_data = (X_val, Y_val),
                       verbose = 1,
                       callbacks = callbacks)
    
    dctr.save(f'{out_dir}/{save_label}_iter_{iteration:02d}.h5')
    
    plt.figure(figsize=(6,5))
    plt.plot(history.history['loss'],     label = 'loss')
    plt.plot(history.history['val_loss'], label = 'val loss')
    plt.legend(loc=0)
    plt.ylabel('loss')
    plt.xlabel('Epochs')
    plt.savefig(f'{out_dir}/{save_label}_iter_{iteration:02d}_history.pdf')

    del history, dctr, callbacks, X_train, X_val, Y_train, Y_val # delete vars to free memory
    K.clear_session()
    gc.collect() # collect garbage to free memory

# %%
data_dir = '/tf/data/BachelorThesis_Data/Valentinas_Samples'

# %%
dataset_up = np.load(f'{data_dir}/test_samples_ready/X1_Train_13TeV_2.305_plot.npz')# hdamp value
print(dataset_up['a'][:10,0,:])

print(np.min(dataset_up['a'][:,0,:], axis = 0))
print(np.max(dataset_up['a'][:,0,:], axis = 0))
# Out:
# [[ 2.08148676  0.6992826  -0.59109546  0.70764628  0.1         1.379     ]
#  [ 2.13661    -1.70731505  2.28662851  0.70556868  0.1         1.379     ]
#  [ 2.16186714  2.03290375  1.99770953  0.7091455   0.1         1.379     ]
#  [ 1.94549652  1.31229885  2.85453456  0.70742535  0.1         1.379     ]
#  [ 2.11433274 -1.11956486 -2.14938315  0.70351428  0.1         1.379     ]
#  [ 1.65173211 -1.6161456   0.87467413  0.7040604   0.1         1.379     ]
#  [ 2.08502436 -1.30460162  1.77656825  0.70665806  0.1         1.379     ]
#  [ 2.43647629  1.33334723 -1.61424266  0.7044473   0.1         1.379     ]
#  [ 2.46671257 -0.5252575   0.54416391  0.71121148  0.1         1.379     ]
#  [ 2.26424266  1.37205437  2.91405565  0.70220938  0.1         1.379     ]]
# [-1.7948258  -4.17589557 -3.14159232  0.32964137  0.1         1.379     ]
# [3.33542968 4.20943493 3.14159231 1.         0.1        1.379     ]

# %%
dataset_nom = np.load(f'{data_dir}/test_samples_ready/X0_Train_13TeV_1.379_plot.npz')
print(dataset_nom['a'][:10,0,:])

print(np.min(dataset_nom['a'][:,0,:], axis = 0))
print(np.max(dataset_nom['a'][:,0,:], axis = 0))
# Out:
# [[ 2.08036261  0.70378566 -0.59099605  0.70764629  0.1         1.379     ]
#  [ 2.03421331 -1.7585162   2.25428646  0.70556868  0.1         1.379     ]
#  [ 2.16052334  2.04118263  1.99775585  0.7091455   0.1         1.379     ]
#  [ 2.11038967  1.36066105 -2.04403781  0.7001572   0.1         1.379     ]
#  [ 1.90231044  0.94453788 -2.28350418  0.70036184  0.1         1.379     ]
#  [ 2.09914199 -0.24509181 -2.2960895   0.72042176  0.1         1.379     ]
#  [ 1.18093296  1.51109212 -2.6413216   0.72837334  0.1         1.379     ]
#  [ 2.12871994 -0.24745518  2.03932809  0.79072319  0.1         1.379     ]
#  [ 2.08599142 -3.03056926 -0.21397835  0.71161655  0.1         1.379     ]
#  [ 1.95338316 -0.96071901  0.43494603  0.70625258  0.1         1.379     ]]
# [-1.73507839 -4.13107874 -3.14159251  0.32964137  0.1         1.379     ]
# [3.43662793 4.14941193 3.14159258 1.         0.1        1.379     ]

# %%
del dataset_up, dataset_nom

# %%
# reverse engineering normalization function
# pt -> np.log10(pt) ?
# rapidity and phi aren't touched
# mass = mass / max(mass) ?
# pid: top:  6->0.1
#     atop: -6->0.2

# hdamp_val: 1.379

def normalize(X):
    X[:,0,0] = np.log10(X[:,0,0]) # log pt
    X[:,1,0] = np.log10(X[:,1,0])
    
    X[:,0,3] = X[:,0,3]/np.max(X[:,0,3]) # mass
    X[:,1,3] = X[:,1,3]/np.max(X[:,1,3]) 
    
    X[:,0,4] = 0.1 # pid
    X[:,1,4] = 0.2
    
    X[:,0,5] = 1.379 # hdamp
    X[:,1,5] = 1.379

    return X

# %%
# convert datasets to normed

data_dir     = '/tf/data/BachelorThesis_Data/Valentinas_Samples'
'''
nominal_list = []
up_list      = []

# X0: up
# X1: nominal

# shape of the datasets in valentinas script was (:, 2, 6)
# shape of the datasets passed to me are         (:, 3, 6)
# so removing 3. entry to be left with only top and anti-top


for i in range(1, 51):
    X0 = []
    X1 = []
    X0_nrm = []
    X1_nrm = []
    
    X0 = np.load(f'{data_dir}/up/Results{i}/2MeventsTrain_2.305_seed{i}_Base1000_13TeV_P4.npz')['a'][:,:-1,:]    
    X1 = np.load(f'{data_dir}/nominal/Results{i}/2MeventsTrain_1.379_seed{i}_Base1000_13TeV_P4.npz')['a'][:,:-1,:] # removing jet

    X0_nrm = np.array(normalize(X0))
    X1_nrm = np.array(normalize(X1))

    np.save(f'{data_dir}/up/Results{i}/2MeventsTrain_2.305_seed{i}_Base1000_13TeV_P4_normed.npy', X0_nrm)
    np.save(f'{data_dir}/nominal/Results{i}/2MeventsTrain_1.379_seed{i}_Base1000_13TeV_P4_normed.npy', X1_nrm)

    del X0, X1, X0_nrm, X1_nrm
    gc.collect()
    
    print(f'loaded and normalized nominal and up datasets: \n\
        up to Results{i}')
'''
# Out:
# loaded and normalized nominal and up datasets:
#         up to Results1
# loaded and normalized nominal and up datasets:
#         up to Results2
# loaded and normalized nominal and up datasets:
#         up to Results3
# loaded and normalized nominal and up datasets:
#         up to Results4
# loaded and normalized nominal and up datasets:
#         up to Results5
# loaded and normalized nominal and up datasets:
#         up to Results6
# loaded and normalized nominal and up datasets:
#         up to Results7
# loaded and normalized nominal and up datasets:
#         up to Results8
# loaded and normalized nominal and up datasets:
#         up to Results9
# loaded and normalized nominal and up datasets:
#         up to Results10
# loaded and normalized nominal and up datasets:
#         up to Results11
# loaded and normalized nominal and up datasets:
#         up to Results12
# loaded and normalized nominal and up datasets:
#         up to Results13
# loaded and normalized nominal and up datasets:
#         up to Results14
# loaded and normalized nominal and up datasets:
#         up to Results15
# loaded and normalized nominal and up datasets:
#         up to Results16
# loaded and normalized nominal and up datasets:
#         up to Results17
# loaded and normalized nominal and up datasets:
#         up to Results18
# loaded and normalized nominal and up datasets:
#         up to Results19
# loaded and normalized nominal and up datasets:
#         up to Results20
# loaded and normalized nominal and up datasets:
#         up to Results21
# loaded and normalized nominal and up datasets:
#         up to Results22
# loaded and normalized nominal and up datasets:
#         up to Results23
# loaded and normalized nominal and up datasets:
#         up to Results24
# loaded and normalized nominal and up datasets:
#         up to Results25
# loaded and normalized nominal and up datasets:
#         up to Results26
# loaded and normalized nominal and up datasets:
#         up to Results27
# loaded and normalized nominal and up datasets:
#         up to Results28
# loaded and normalized nominal and up datasets:
#         up to Results29
# loaded and normalized nominal and up datasets:
#         up to Results30
# loaded and normalized nominal and up datasets:
#         up to Results31
# loaded and normalized nominal and up datasets:
#         up to Results32
# loaded and normalized nominal and up datasets:
#         up to Results33
# loaded and normalized nominal and up datasets:
#         up to Results34
# loaded and normalized nominal and up datasets:
#         up to Results35
# loaded and normalized nominal and up datasets:
#         up to Results36
# loaded and normalized nominal and up datasets:
#         up to Results37
# loaded and normalized nominal and up datasets:
#         up to Results38
# loaded and normalized nominal and up datasets:
#         up to Results39
# loaded and normalized nominal and up datasets:
#         up to Results40
# loaded and normalized nominal and up datasets:
#         up to Results41
# loaded and normalized nominal and up datasets:
#         up to Results42
# loaded and normalized nominal and up datasets:
#         up to Results43
# loaded and normalized nominal and up datasets:
#         up to Results44
# loaded and normalized nominal and up datasets:
#         up to Results45
# loaded and normalized nominal and up datasets:
#         up to Results46
# loaded and normalized nominal and up datasets:
#         up to Results47
# loaded and normalized nominal and up datasets:
#         up to Results48
# loaded and normalized nominal and up datasets:
#         up to Results49
# loaded and normalized nominal and up datasets:
#         up to Results50

# %%
# load normed datasets

data_dir     = '/tf/data/BachelorThesis_Data/Valentinas_Samples'

nominal_list = []
up_list      = []

# X0: up
# X1: nominal
X0_nrm = []
X1_nrm = []


for i in range(1, 51):
    X0_nrm.extend(np.load(f'{data_dir}/up/Results{i}/2MeventsTrain_2.305_seed{i}_Base1000_13TeV_P4_normed.npy'))
    X1_nrm.extend(np.load(f'{data_dir}/nominal/Results{i}/2MeventsTrain_1.379_seed{i}_Base1000_13TeV_P4_normed.npy'))
    if not i%5: 
        print(f'loaded and added normalized nominal and up datasets: \n\
            up to Results{i}')

X0_nrm = np.array(X0_nrm)
X1_nrm = np.array(X1_nrm)

print(f'{X0_nrm.shape}')
print(f'{X1_nrm.shape}')

gc.collect()
# Out:
# loaded and added normalized nominal and up datasets:
#             up to Results5
# loaded and added normalized nominal and up datasets:
#             up to Results10
# loaded and added normalized nominal and up datasets:
#             up to Results15
# loaded and added normalized nominal and up datasets:
#             up to Results20
# loaded and added normalized nominal and up datasets:
#             up to Results25
# loaded and added normalized nominal and up datasets:
#             up to Results30
# loaded and added normalized nominal and up datasets:
#             up to Results35
# loaded and added normalized nominal and up datasets:
#             up to Results40
# loaded and added normalized nominal and up datasets:
#             up to Results45
# loaded and added normalized nominal and up datasets:
#             up to Results50
# (99989274, 2, 6)
# (99053382, 2, 6)
# 682

# %%
# cheack datasets
'''
for part in range(2):
    for arg in range(6):
        print(f'{np.mean(X0_nrm[:, part, arg]) = :.3f}')
        print(f'{np.mean(X1_nrm[:, part, arg]) = :.3f}')
'''
# Out:
# np.mean(X0_nrm[:, part, arg]) = 1.997
# np.mean(X1_nrm[:, part, arg]) = 1.996
# np.mean(X0_nrm[:, part, arg]) = -0.000
# np.mean(X1_nrm[:, part, arg]) = 0.000
# np.mean(X0_nrm[:, part, arg]) = 0.000
# np.mean(X1_nrm[:, part, arg]) = 0.000
# np.mean(X0_nrm[:, part, arg]) = 0.705
# np.mean(X1_nrm[:, part, arg]) = 0.705
# np.mean(X0_nrm[:, part, arg]) = 0.100
# np.mean(X1_nrm[:, part, arg]) = 0.100
# np.mean(X0_nrm[:, part, arg]) = 1.379
# np.mean(X1_nrm[:, part, arg]) = 1.379
# np.mean(X0_nrm[:, part, arg]) = 1.998
# np.mean(X1_nrm[:, part, arg]) = 1.997
# np.mean(X0_nrm[:, part, arg]) = -0.000
# np.mean(X1_nrm[:, part, arg]) = 0.000
# np.mean(X0_nrm[:, part, arg]) = -0.000
# np.mean(X1_nrm[:, part, arg]) = 0.000
# np.mean(X0_nrm[:, part, arg]) = 0.705
# np.mean(X1_nrm[:, part, arg]) = 0.705
# np.mean(X0_nrm[:, part, arg]) = 0.200
# np.mean(X1_nrm[:, part, arg]) = 0.200
# np.mean(X0_nrm[:, part, arg]) = 1.379
# np.mean(X1_nrm[:, part, arg]) = 1.379

# %%
# train 20 iterations and save the model each time using the predefined functions
# taking 40 million random samples from each dataset (containing 99 million + events) for each iteration

for i in range(1, 21):
    train_single_iteration(X0_nrm, X1_nrm, iteration=i)
# Out:
# 2024-06-12 09:09:01.866445: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 09:09:01.870044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:09:01.870559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:09:01.870769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:09:02.381555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:09:02.381788: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:09:02.381986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-12 09:09:02.382406: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6140 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:09:00.0, compute capability: 7.5
# Starting training
# 2024-06-12 09:09:02.795696: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2880000000 exceeds 10% of free system memory.
# 2024-06-12 09:09:03.530714: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2880000000 exceeds 10% of free system memory.
# Epoch 1/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6958 - acc: 0.5023
# Epoch 1: val_loss improved from inf to 0.69323, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 21s 12ms/step - loss: 0.6958 - acc: 0.5023 - val_loss: 0.6932 - val_acc: 0.5035
# Epoch 2/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6932 - acc: 0.5034
# Epoch 2: val_loss improved from 0.69323 to 0.69309, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 17s 12ms/step - loss: 0.6932 - acc: 0.5034 - val_loss: 0.6931 - val_acc: 0.5048
# Epoch 3/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5044
# Epoch 3: val_loss improved from 0.69309 to 0.69303, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5044 - val_loss: 0.6930 - val_acc: 0.5059
# Epoch 4/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5051
# Epoch 4: val_loss did not improve from 0.69303
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5051 - val_loss: 0.6930 - val_acc: 0.5054
# Epoch 5/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5058
# Epoch 5: val_loss improved from 0.69303 to 0.69302, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5058 - val_loss: 0.6930 - val_acc: 0.5066
# Epoch 6/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5061
# Epoch 6: val_loss did not improve from 0.69302
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5061 - val_loss: 0.6930 - val_acc: 0.5062
# Epoch 7/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5066
# Epoch 7: val_loss improved from 0.69302 to 0.69302, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5066 - val_loss: 0.6930 - val_acc: 0.5065
# Epoch 8/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5067
# Epoch 8: val_loss improved from 0.69302 to 0.69298, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5067 - val_loss: 0.6930 - val_acc: 0.5071
# Epoch 9/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5070
# Epoch 9: val_loss improved from 0.69298 to 0.69298, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5070 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 10/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5072
# Epoch 10: val_loss did not improve from 0.69298
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5072 - val_loss: 0.6930 - val_acc: 0.5069
# Epoch 11/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5073
# Epoch 11: val_loss improved from 0.69298 to 0.69297, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5073 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 12/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5073
# Epoch 12: val_loss improved from 0.69297 to 0.69296, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5073 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 13/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5074
# Epoch 13: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5074 - val_loss: 0.6930 - val_acc: 0.5061
# Epoch 14/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5074
# Epoch 14: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5074 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 15/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 15: val_loss improved from 0.69296 to 0.69295, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 16/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 16: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 17/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 17: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 18/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 18: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 19/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 19: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 20/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 20: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 21/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 21: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 22/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 22: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 23/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 23: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 24/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 24: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5079
# Epoch 25/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 25: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 26/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 26: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 27/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 27: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5079
# Epoch 28/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 28: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 29/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 29: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 30/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 30: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 31/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5078
# Epoch 31: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 32/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5077
# Epoch 32: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 33/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 33: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 34/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 34: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 35/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 35: val_loss improved from 0.69295 to 0.69294, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5080
# Epoch 36/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 36: val_loss improved from 0.69294 to 0.69294, saving model to ./saved_models/DCTR_training_iter_01.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5080
# Epoch 37/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 37: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 38/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 38: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5079
# Epoch 39/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 39: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 40/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 40: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 41/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 41: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 42/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 42: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 43/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 43: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 44/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 44: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5080
# Epoch 45/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 45: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 46/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 46: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 47/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 47: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 48/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 48: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 49/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 49: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 50/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 50: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 51/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 51: val_loss did not improve from 0.69294
# Restoring model weights from the end of the best epoch: 36.
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 51: early stopping
# Starting training
# 2024-06-12 09:24:43.614654: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2880000000 exceeds 10% of free system memory.
# 2024-06-12 09:24:44.294126: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2880000000 exceeds 10% of free system memory.
# Epoch 1/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6952 - acc: 0.5023
# Epoch 1: val_loss improved from inf to 0.69316, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 21s 13ms/step - loss: 0.6952 - acc: 0.5023 - val_loss: 0.6932 - val_acc: 0.5028
# Epoch 2/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.5036
# Epoch 2: val_loss improved from 0.69316 to 0.69309, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6932 - acc: 0.5036 - val_loss: 0.6931 - val_acc: 0.5051
# Epoch 3/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5047
# Epoch 3: val_loss improved from 0.69309 to 0.69304, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5047 - val_loss: 0.6930 - val_acc: 0.5044
# Epoch 4/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5051
# Epoch 4: val_loss did not improve from 0.69304
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5051 - val_loss: 0.6931 - val_acc: 0.5041
# Epoch 5/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5057
# Epoch 5: val_loss improved from 0.69304 to 0.69300, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5057 - val_loss: 0.6930 - val_acc: 0.5070
# Epoch 6/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5061
# Epoch 6: val_loss did not improve from 0.69300
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5061 - val_loss: 0.6930 - val_acc: 0.5055
# Epoch 7/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5064
# Epoch 7: val_loss improved from 0.69300 to 0.69299, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5064 - val_loss: 0.6930 - val_acc: 0.5070
# Epoch 8/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5069
# Epoch 8: val_loss improved from 0.69299 to 0.69298, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5069 - val_loss: 0.6930 - val_acc: 0.5072
# Epoch 9/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5070
# Epoch 9: val_loss did not improve from 0.69298
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5070 - val_loss: 0.6930 - val_acc: 0.5070
# Epoch 10/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5071
# Epoch 10: val_loss improved from 0.69298 to 0.69297, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5071 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 11/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5073
# Epoch 11: val_loss improved from 0.69297 to 0.69296, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5073 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 12/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5074
# Epoch 12: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5074 - val_loss: 0.6930 - val_acc: 0.5071
# Epoch 13/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 13: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5060
# Epoch 14/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 14: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 15/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 15: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 16/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 16: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 17/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 17: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 18/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 18: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 19/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 19: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 20/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 20: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 21/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 21: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 22/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 22: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 23/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5078
# Epoch 23: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 24/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 24: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 25/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 25: val_loss improved from 0.69296 to 0.69295, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 26/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 26: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 27/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 27: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 28/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 28: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 29/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 29: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 30/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 30: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 31/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 31: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 32/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 32: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 33/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 33: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 34/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 34: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 35/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 35: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 36/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 36: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 37/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 37: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 38/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 38: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 39/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 39: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 40/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 40: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 41/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 41: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_02.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 42/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 42: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 43/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 43: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 44/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 44: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 45/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 45: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 46/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 46: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 47/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 47: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 48/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 48: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 49/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 49: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 17s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 50/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 50: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 51/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 51: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 17s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 52/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 52: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 17s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 53/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5081
# Epoch 53: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5081 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 54/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5081
# Epoch 54: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5081 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 55/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5081
# Epoch 55: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5081 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 56/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 56: val_loss did not improve from 0.69295
# Restoring model weights from the end of the best epoch: 41.
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 56: early stopping
# Starting training
# 2024-06-12 09:41:57.822765: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2880000000 exceeds 10% of free system memory.
# Epoch 1/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6953 - acc: 0.5025
# Epoch 1: val_loss improved from inf to 0.69314, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 21s 13ms/step - loss: 0.6953 - acc: 0.5025 - val_loss: 0.6931 - val_acc: 0.5035
# Epoch 2/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5037
# Epoch 2: val_loss improved from 0.69314 to 0.69310, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5038 - val_loss: 0.6931 - val_acc: 0.5051
# Epoch 3/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5044
# Epoch 3: val_loss improved from 0.69310 to 0.69304, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5044 - val_loss: 0.6930 - val_acc: 0.5058
# Epoch 4/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5050
# Epoch 4: val_loss improved from 0.69304 to 0.69303, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5050 - val_loss: 0.6930 - val_acc: 0.5057
# Epoch 5/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5055
# Epoch 5: val_loss improved from 0.69303 to 0.69302, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5055 - val_loss: 0.6930 - val_acc: 0.5058
# Epoch 6/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5062
# Epoch 6: val_loss improved from 0.69302 to 0.69300, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5062 - val_loss: 0.6930 - val_acc: 0.5063
# Epoch 7/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5064
# Epoch 7: val_loss did not improve from 0.69300
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5064 - val_loss: 0.6930 - val_acc: 0.5059
# Epoch 8/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5068
# Epoch 8: val_loss improved from 0.69300 to 0.69298, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5068 - val_loss: 0.6930 - val_acc: 0.5071
# Epoch 9/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5069
# Epoch 9: val_loss improved from 0.69298 to 0.69297, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5069 - val_loss: 0.6930 - val_acc: 0.5071
# Epoch 10/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5072
# Epoch 10: val_loss improved from 0.69297 to 0.69296, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5072 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 11/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5073
# Epoch 11: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5073 - val_loss: 0.6930 - val_acc: 0.5071
# Epoch 12/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5073
# Epoch 12: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5073 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 13/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5074
# Epoch 13: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5074 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 14/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 14: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 15/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 15: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 16/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 16: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 17/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 17: val_loss improved from 0.69296 to 0.69295, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 18/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 18: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 19/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 19: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 20/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 20: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 21/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 21: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 22/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 22: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 23/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 23: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 24/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 24: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 25/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5077
# Epoch 25: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 26/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 26: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 27/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 27: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 28/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5077
# Epoch 28: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 29/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 29: val_loss improved from 0.69295 to 0.69294, saving model to ./saved_models/DCTR_training_iter_03.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 30/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 30: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 31/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 31: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 32/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 32: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 33/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 33: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 34/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 34: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 35/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 35: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 36/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 36: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 37/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 37: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 38/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 38: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 39/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 39: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 40/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 40: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 41/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 41: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 42/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 42: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5079
# Epoch 43/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 43: val_loss did not improve from 0.69294
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 44/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 44: val_loss did not improve from 0.69294
# Restoring model weights from the end of the best epoch: 29.
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 44: early stopping
# Starting training
# Epoch 1/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6948 - acc: 0.5023
# Epoch 1: val_loss improved from inf to 0.69326, saving model to ./saved_models/DCTR_training_iter_04.h5
# 1465/1465 [==============================] - 21s 13ms/step - loss: 0.6948 - acc: 0.5023 - val_loss: 0.6933 - val_acc: 0.5017
# Epoch 2/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6932 - acc: 0.5035
# Epoch 2: val_loss improved from 0.69326 to 0.69315, saving model to ./saved_models/DCTR_training_iter_04.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6932 - acc: 0.5035 - val_loss: 0.6931 - val_acc: 0.5019
# Epoch 3/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5045
# Epoch 3: val_loss improved from 0.69315 to 0.69304, saving model to ./saved_models/DCTR_training_iter_04.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5045 - val_loss: 0.6930 - val_acc: 0.5046
# Epoch 4/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5050
# Epoch 4: val_loss did not improve from 0.69304
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5050 - val_loss: 0.6931 - val_acc: 0.5053
# Epoch 5/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5054
# Epoch 5: val_loss improved from 0.69304 to 0.69302, saving model to ./saved_models/DCTR_training_iter_04.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5054 - val_loss: 0.6930 - val_acc: 0.5063
# Epoch 6/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5058
# Epoch 6: val_loss did not improve from 0.69302
# ...
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 19/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 19: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 20/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 20: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5072
# Epoch 21/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5076
# Epoch 21: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5076 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 22/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 22: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 23/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 23: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 17s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 24/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 24: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_17.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6929 - val_acc: 0.5078
# Epoch 25/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 25: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 26/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 26: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 27/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5077
# Epoch 27: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 28/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 28: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 29/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5077
# Epoch 29: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5077 - val_loss: 0.6930 - val_acc: 0.5071
# Epoch 30/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 30: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 31/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 31: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 32/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 32: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 33/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 33: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 34/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 34: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 35/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 35: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 36/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 36: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 37/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 37: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 38/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 38: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_17.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5077
# Epoch 39/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 39: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 40/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 40: val_loss improved from 0.69295 to 0.69295, saving model to ./saved_models/DCTR_training_iter_17.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6929 - val_acc: 0.5077
# Epoch 41/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5078
# Epoch 41: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5078 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 42/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 42: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 43/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 43: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 44/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 44: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 45/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 45: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 46/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 46: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 47/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 47: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 48/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 48: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6929 - val_acc: 0.5077
# Epoch 49/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 49: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 50/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 50: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5074
# Epoch 51/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5080
# Epoch 51: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 52/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 52: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 53/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 53: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 54/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 54: val_loss did not improve from 0.69295
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5077
# Epoch 55/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6929 - acc: 0.5079
# Epoch 55: val_loss did not improve from 0.69295
# Restoring model weights from the end of the best epoch: 40.
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6929 - acc: 0.5079 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 55: early stopping
# Starting training
# Epoch 1/1000
# 1465/1465 [==============================] - ETA: 0s - loss: 0.6973 - acc: 0.5021
# Epoch 1: val_loss improved from inf to 0.69317, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 21s 13ms/step - loss: 0.6973 - acc: 0.5021 - val_loss: 0.6932 - val_acc: 0.5033
# Epoch 2/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6933 - acc: 0.5030
# Epoch 2: val_loss improved from 0.69317 to 0.69311, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6933 - acc: 0.5030 - val_loss: 0.6931 - val_acc: 0.5045
# Epoch 3/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5037
# Epoch 3: val_loss improved from 0.69311 to 0.69306, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5037 - val_loss: 0.6931 - val_acc: 0.5039
# Epoch 4/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5045
# Epoch 4: val_loss did not improve from 0.69306
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5045 - val_loss: 0.6932 - val_acc: 0.5044
# Epoch 5/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6931 - acc: 0.5048
# Epoch 5: val_loss did not improve from 0.69306
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6931 - acc: 0.5048 - val_loss: 0.6931 - val_acc: 0.5020
# Epoch 6/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5053
# Epoch 6: val_loss improved from 0.69306 to 0.69302, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5053 - val_loss: 0.6930 - val_acc: 0.5061
# Epoch 7/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5058
# Epoch 7: val_loss improved from 0.69302 to 0.69299, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5058 - val_loss: 0.6930 - val_acc: 0.5070
# Epoch 8/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5065
# Epoch 8: val_loss improved from 0.69299 to 0.69299, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5065 - val_loss: 0.6930 - val_acc: 0.5070
# Epoch 9/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5068
# Epoch 9: val_loss improved from 0.69299 to 0.69297, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5068 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 10/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5070
# Epoch 10: val_loss did not improve from 0.69297
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5070 - val_loss: 0.6930 - val_acc: 0.5068
# Epoch 11/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5072
# Epoch 11: val_loss improved from 0.69297 to 0.69297, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5072 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 12/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5072
# Epoch 12: val_loss improved from 0.69297 to 0.69296, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5072 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 13/1000
# 1460/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5073
# Epoch 13: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5073 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 14/1000
# 1461/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5074
# Epoch 14: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5074 - val_loss: 0.6930 - val_acc: 0.5076
# Epoch 15/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5074
# Epoch 15: val_loss improved from 0.69296 to 0.69296, saving model to ./saved_models/DCTR_training_iter_18.h5
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5074 - val_loss: 0.6930 - val_acc: 0.5078
# Epoch 16/1000
# 1462/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 16: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 17/1000
# 1464/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 17: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 18/1000
# 1463/1465 [============================>.] - ETA: 0s - loss: 0.6930 - acc: 0.5075
# Epoch 18: val_loss did not improve from 0.69296
# 1465/1465 [==============================] - 18s 12ms/step - loss: 0.6930 - acc: 0.5075 - val_loss: 0.6930 - val_acc: 0.5073
# Epoch 19/1000
#  718/1465 [=============>................] - ETA: 7s - loss: 0.6930 - acc: 0.5077
