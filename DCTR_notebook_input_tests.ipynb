# %%
# import standard modules and DCTR
import sys
import numpy as np
import math
import tensorflow as tf

# import DCTR
path_to_DCTR = '/tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/' # modify as needed
sys.path.append(path_to_DCTR)
import DCTR

# make sure GPU usage is enabled
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from importlib import reload
reload(DCTR)
# Out:
# <module 'DCTR' from '/tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/DCTR.py'>

# %% [markdown]
# # load data

# %%
# Load Datasets: MiNNLO: X1 | POWHEG hvq: X0
# all particles arrays

X0_test = []
# POWHEG hvq
# args: filePath, i=number of particles to load
X0_test = DCTR.load_dataset('/tf/data/BachelorThesis_Data/LHE/data/POWHEG_hvq/converted_lhe.npz', i=4)
print('POWHEG hvq X0_test.shape: '+str(X0_test.shape))

X1_test = []
# MiNNLO
X1_test = DCTR.load_dataset('/tf/data/BachelorThesis_Data/LHE/data/MiNNLO/converted_lhe.npz', i=4)
print('MiNNLO     X1_test.shape: '+str(X1_test.shape))
# Out:
# POWHEG hvq X0_test.shape: (29605180, 4, 9)
# MiNNLO     X1_test.shape: (9553938, 4, 9)

# %%
# Load pre-normed Datasets: MiNNLO: X1 | POWHEG hvq: X0
# only contain tt-pair every event has order: 
# tt-pair, top, anti-top

# every particle has arguments: 
# [pt, rapidity, phi, mass, eta, E, PID, w, theta]
# [0 , 1       , 2  , 3   , 4  , 5, 6  , 7, 8    ]


X0_nrm = []
X1_nrm = []

# POWHEG hvq
X0_nrm = DCTR.load_dataset('/tf/data/BachelorThesis_Data/LHE/data/POWHEG_hvq/normed_lhe.npz')
print('POWHEG hvq all particles X0.shape: '+str(X0_nrm.shape))

# MiNNLO
X1_nrm = DCTR.load_dataset('/tf/data/BachelorThesis_Data/LHE/data/MiNNLO/normed_lhe.npz')
print('MiNNLO all particles X1.shape: '+str(X1_nrm.shape))
# Out:
# POWHEG hvq all particles X0.shape: (29605180, 3, 9)
# MiNNLO all particles X1.shape: (9553938, 3, 9)

# %%
# get normalized event generator weights
X0_nrm_wgt = X0_nrm[:, 0, 7].copy()
X1_nrm_wgt = X1_nrm[:, 0, 7].copy()

# %%
# delete eta (pseudorpaidity) because neural network was too good at classifiying
X0_nrm = np.delete(X0_nrm, 4, -1)
X1_nrm = np.delete(X1_nrm, 4, -1)

# %% [markdown]
# # prep data for training

# %%
# prep arrays for the neural network

# prep_arrays() necessary args:
# X0, X1
# prep_arrays() default args:
# val=0.15, shuffle=True, use_class_weights=False

# strips theta parameter from datasets and creates Y classifier arrays
# strips wgts from datasets and creates wgt arrays | if use_class_weights==True: -> give over represented dataset smaller weights 
# splits arrays into training and validation datasets accroding to val
# splits arrays into training and validation datasets accroding to val

X_train, X_val, Y_train, Y_val, wgt_train, wgt_val = DCTR.prep_arrays(X0_nrm, X1_nrm, val=0.2)

# %% [markdown]
# # train DCTR neural network

# %%
# remove tt-pair from training: first index from second axis
# X_train, X_val, Y_train, Y_val, wgt_train, wgt_val = DCTR.prep_arrays(X0_nrm[:,1:,:], X1_nrm[:,1:,:], val=0.2)

dctr, callbacks = DCTR.setup_nn(input_dim=6, patience=15, saveLabel='DCTR_training_no_tt', loss='mse')
# DCTR.train(dctr, callbacks, X_train, Y_train, X_val, Y_val, wgt_train=wgt_train, wgt_val=wgt_val, epochs=200, batch_size=8192*32, saveLabel='DCTR_training_no_tt')
dctr.load_weights('DCTR_training_no_tt.h5')
with tf.device('/device:cpu:0'):
    weights_0_no_tt, _ = DCTR.predict_weights(dctr, X0_nrm[:,1:,:-2], X1_nrm[:,1:,:-2], batch_size=8192*16)
# Out:
# 226/226 [==============================] - 27s 117ms/step
# 73/73 [==============================] - 9s 115ms/step

# %%
X_train, X_val, Y_train, Y_val, wgt_train, wgt_val = DCTR.prep_arrays(X0_nrm, X1_nrm, val=0.2)
# remove Energy from training: last index from last axis
with tf.device('/device:cpu:0'):
    X_train = tf.constant(X_train[:,:,:-1])
    X_val = tf.constant(X_val[:,:,:-1])

dctr, callbacks = DCTR.setup_nn(input_dim=5, patience=15, saveLabel='DCTR_training_no_E', loss='mse')
DCTR.train(dctr, callbacks, X_train, Y_train, X_val, Y_val, wgt_train=wgt_train, wgt_val=wgt_val, epochs=200, batch_size=8192*32, saveLabel='DCTR_training_no_E')

with tf.device('/device:cpu:0'):
    weights_0_no_E, _ = DCTR.predict_weights(dctr, X0_nrm[:,:,:-3], X1_nrm[:,:,:-3], batch_size=8192*16)
# Out:
# Epoch 1/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1652 - acc: 0.7538
# Epoch 1: val_loss improved from inf to 0.15334, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 14s 95ms/step - loss: 0.1651 - acc: 0.7538 - val_loss: 0.1533 - val_acc: 0.7560 - lr: 0.0010
# Epoch 2/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1530 - acc: 0.7564
# Epoch 2: val_loss improved from 0.15334 to 0.15267, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1530 - acc: 0.7564 - val_loss: 0.1527 - val_acc: 0.7566 - lr: 0.0010
# Epoch 3/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1525 - acc: 0.7572
# Epoch 3: val_loss improved from 0.15267 to 0.15233, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1525 - acc: 0.7572 - val_loss: 0.1523 - val_acc: 0.7576 - lr: 0.0010
# Epoch 4/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1523 - acc: 0.7579
# Epoch 4: val_loss improved from 0.15233 to 0.15211, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1523 - acc: 0.7579 - val_loss: 0.1521 - val_acc: 0.7582 - lr: 0.0010
# Epoch 5/200
# 120/120 [==============================] - ETA: 0s - loss: 0.1521 - acc: 0.7585
# Epoch 5: val_loss improved from 0.15211 to 0.15210, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1521 - acc: 0.7585 - val_loss: 0.1521 - val_acc: 0.7581 - lr: 0.0010
# Epoch 6/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1520 - acc: 0.7589
# Epoch 6: val_loss improved from 0.15210 to 0.15186, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 10s 87ms/step - loss: 0.1520 - acc: 0.7589 - val_loss: 0.1519 - val_acc: 0.7586 - lr: 0.0010
# Epoch 7/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1518 - acc: 0.7593
# Epoch 7: val_loss improved from 0.15186 to 0.15180, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1518 - acc: 0.7593 - val_loss: 0.1518 - val_acc: 0.7591 - lr: 0.0010
# Epoch 8/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1518 - acc: 0.7595
# Epoch 8: val_loss improved from 0.15180 to 0.15168, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1518 - acc: 0.7595 - val_loss: 0.1517 - val_acc: 0.7593 - lr: 0.0010
# Epoch 9/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.
200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7604
# Epoch 23: val_loss improved from 0.15129 to 0.15127, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1513 - acc: 0.7604 - val_loss: 0.1513 - val_acc: 0.7603 - lr: 8.6071e-04
# Epoch 24/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7604
# Epoch 24: val_loss did not improve from 0.15127
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1513 - acc: 0.7604 - val_loss: 0.1513 - val_acc: 0.7602 - lr: 8.4366e-04
# Epoch 25/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7604
# Epoch 25: val_loss improved from 0.15127 to 0.15126, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1513 - acc: 0.7604 - val_loss: 0.1513 - val_acc: 0.7605 - lr: 8.2696e-04
# Epoch 26/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7604
# Epoch 26: val_loss improved from 0.15126 to 0.15124, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1512 - acc: 0.7604 - val_loss: 0.1512 - val_acc: 0.7604 - lr: 8.1058e-04
# Epoch 27/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7604
# Epoch 27: val_loss did not improve from 0.15124
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1512 - acc: 0.7604 - val_loss: 0.1512 - val_acc: 0.7602 - lr: 7.9453e-04
# Epoch 28/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7604
# Epoch 28: val_loss did not improve from 0.15124
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1512 - acc: 0.7604 - val_loss: 0.1512 - val_acc: 0.7605 - lr: 7.7880e-04
# Epoch 29/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7604
# Epoch 29: val_loss improved from 0.15124 to 0.15124, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1512 - acc: 0.7604 - val_loss: 0.1512 - val_acc: 0.7605 - lr: 7.6338e-04
# Epoch 30/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7604
# Epoch 30: val_loss improved from 0.15124 to 0.15122, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1512 - acc: 0.7604 - val_loss: 0.1512 - val_acc: 0.7602 - lr: 7.4826e-04
# Epoch 31/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7605
# Epoch 31: val_loss improved from 0.15122 to 0.15121, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1512 - acc: 0.7605 - val_loss: 0.1512 - val_acc: 0.7604 - lr: 7.3345e-04
# Epoch 32/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7605
# Epoch 32: val_loss improved from 0.15121 to 0.15120, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1512 - acc: 0.7605 - val_loss: 0.1512 - val_acc: 0.7603 - lr: 7.1892e-04
# Epoch 33/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7605
# Epoch 33: val_loss improved from 0.15120 to 0.15119, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1512 - acc: 0.7605 - val_loss: 0.1512 - val_acc: 0.7604 - lr: 7.0469e-04
# Epoch 34/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.7605
# Epoch 34: val_loss improved from 0.15119 to 0.15119, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1512 - acc: 0.7605 - val_loss: 0.1512 - val_acc: 0.7604 - lr: 6.9073e-04
# Epoch 35/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7605
# Epoch 35: val_loss did not improve from 0.15119
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1511 - acc: 0.7605 - val_loss: 0.1512 - val_acc: 0.7607 - lr: 6.7706e-04
# Epoch 36/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7605
# Epoch 36: val_loss improved from 0.15119 to 0.15117, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1511 - acc: 0.7605 - val_loss: 0.1512 - val_acc: 0.7603 - lr: 6.6365e-04
# Epoch 37/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7605
# Epoch 37: val_loss did not improve from 0.15117
# 120/120 [==============================] - 11s 90ms/step - loss: 0.
200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7606
# Epoch 51: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1511 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7605 - lr: 4.9164e-04
# Epoch 52/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7606
# Epoch 52: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1511 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7606 - lr: 4.8191e-04
# Epoch 53/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7606
# Epoch 53: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1511 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 4.7237e-04
# Epoch 54/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7606
# Epoch 54: val_loss improved from 0.15114 to 0.15114, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1511 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7602 - lr: 4.6301e-04
# Epoch 55/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 55: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1511 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 4.5384e-04
# Epoch 56/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 56: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7605 - lr: 4.4486e-04
# Epoch 57/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1511 - acc: 0.7606
# Epoch 57: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7608 - lr: 4.3605e-04
# Epoch 58/200
# 120/120 [==============================] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 58: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 4.2742e-04
# Epoch 59/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 59: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7607 - lr: 4.1895e-04
# Epoch 60/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 60: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7606 - lr: 4.1066e-04
# Epoch 61/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 61: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 4.0252e-04
# Epoch 62/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 62: val_loss did not improve from 0.15114
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7605 - lr: 3.9455e-04
# Epoch 63/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 63: val_loss improved from 0.15114 to 0.15113, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7602 - lr: 3.8674e-04
# Epoch 64/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 64: val_loss did not improve from 0.15113
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 3.7908e-04
# Epoch 65/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 65: val_loss improved from 0.15113 to 0.15113, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 3.7158e-04
# Epoch 66/200
# 120/120 [==============================] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 66: val_loss improved from 0.15113 to 0.15112, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 3.6422e-04
# Epoch 67/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 67: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7602 - lr: 3.5701e-04
# Epoch 68/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 68: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 3.4994e-04
# Epoch 69/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 69: val_loss improved from 0.15112 to 0.15112, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 3.4301e-04
# Epoch 70/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 70: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7604 - lr: 3.3622e-04
# Epoch 71/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 71: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 3.2956e-04
# Epoch 72/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 72: val_loss improved from 0.15112 to 0.15112, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7603 - lr: 3.2303e-04
# Epoch 73/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 73: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 3.1664e-04
# Epoch 74/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 74: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 3.1037e-04
# Epoch 75/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 75: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 3.0422e-04
# Epoch 76/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 76: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 2.9820e-04
# Epoch 77/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 77: val_loss improved from 0.15112 to 0.15112, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 2.9229e-04
# Epoch 78/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 78: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1512 - val_acc: 0.7607 - lr: 2.8650e-04
# Epoch 79/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 79: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 2.8083e-04
# Epoch 80/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 80: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 2.7527e-04
# Epoch 81/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 81: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7603 - lr: 2.6982e-04
# Epoch 82/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 82: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 2.6448e-04
# Epoch 83/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7606
# Epoch 83: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7606 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 2.5924e-04
# Epoch 84/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 84: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7601 - lr: 2.5411e-04
# Epoch 85/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 85: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 2.4908e-04
# Epoch 86/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 86: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 2.4414e-04
# Epoch 87/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 87: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 2.3931e-04
# Epoch 88/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 88: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 2.3457e-04
# Epoch 89/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 89: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 2.2993e-04
# Epoch 90/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 90: val_loss did not improve from 0.15112
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7602 - lr: 2.2537e-04
# Epoch 91/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 91: val_loss improved from 0.15112 to 0.15111, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 2.2091e-04
# Epoch 92/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.7607
# Epoch 92: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1510 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 2.1654e-04
# Epoch 93/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 93: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 2.1225e-04
# Epoch 94/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 94: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 90ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7601 - lr: 2.0805e-04
# Epoch 95/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 95: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 91ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 2.0393e-04
# Epoch 96/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 96: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.9989e-04
# Epoch 97/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 97: val_loss did not improve from 0.15111
# 120/120 [==============================] - 10s 87ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.9593e-04
# Epoch 98/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 98: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.9205e-04
# Epoch 99/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 99: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.8825e-04
# Epoch 100/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 100: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.8452e-04
# Epoch 101/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 101: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.8087e-04
# Epoch 102/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 102: val_loss improved from 0.15111 to 0.15111, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 1.7728e-04
# Epoch 103/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 103: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 1.7377e-04
# Epoch 104/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 104: val_loss did not improve from 0.15111
# 120/120 [==============================] - 10s 87ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.7033e-04
# Epoch 105/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 105: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.6696e-04
# Epoch 106/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 106: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 1.6365e-04
# Epoch 107/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 107: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.6041e-04
# Epoch 108/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 108: val_loss did not improve from 0.15111
# 120/120 [==============================] - 10s 87ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.5724e-04
# Epoch 109/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 109: val_loss did not improve from 0.15111
# 120/120 [==============================] - 10s 87ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.5412e-04
# Epoch 110/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 110: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.5107e-04
# Epoch 111/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 111: val_loss improved from 0.15111 to 0.15111, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.4808e-04
# Epoch 112/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 112: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1512 - val_acc: 0.7607 - lr: 1.4515e-04
# Epoch 113/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 113: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7603 - lr: 1.4227e-04
# Epoch 114/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 114: val_loss improved from 0.15111 to 0.15111, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.3946e-04
# Epoch 115/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 115: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 1.3670e-04
# Epoch 116/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 116: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 1.3399e-04
# Epoch 117/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 117: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 1.3134e-04
# Epoch 118/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 118: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.2874e-04
# Epoch 119/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 119: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 1.2619e-04
# Epoch 120/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 120: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.2369e-04
# Epoch 121/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 121: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7607 - lr: 1.2124e-04
# Epoch 122/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 122: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7604 - lr: 1.1884e-04
# Epoch 123/200
# 120/120 [==============================] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 123: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 89ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.1648e-04
# Epoch 124/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 124: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7605 - lr: 1.1418e-04
# Epoch 125/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 125: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 1.1192e-04
# Epoch 126/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 126: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7602 - lr: 1.0970e-04
# Epoch 127/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 127: val_loss did not improve from 0.15111
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 1.0753e-04
# Epoch 128/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 128: val_loss did not improve from 0.15111
# 120/120 [==============================] - 10s 87ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7603 - lr: 1.0540e-04
# Epoch 129/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.7607
# Epoch 129: val_loss did not improve from 0.15111
# Restoring model weights from the end of the best epoch: 114.
# 120/120 [==============================] - 11s 88ms/step - loss: 0.1509 - acc: 0.7607 - val_loss: 0.1511 - val_acc: 0.7606 - lr: 1.0331e-04
# Epoch 129: early stopping
# 226/226 [==============================] - 35s 151ms/step
# 73/73 [==============================] - 11s 150ms/step

# %%
# remove Energy and tt-pair from training: first index from second axis and last index from last axis
X_train, X_val, Y_train, Y_val, wgt_train, wgt_val = DCTR.prep_arrays(X0_nrm, X1_nrm, val=0.2)
with tf.device('/device:cpu:0'):
    X_train = tf.constant(X_train[:,1:,:-1])
    X_val = tf.constant(X_val[:,1:,:-1])

dctr, callbacks = DCTR.setup_nn(input_dim=5, patience=15, saveLabel='DCTR_training_no_tt_E', loss='mse')
DCTR.train(dctr, callbacks, X_train, Y_train, X_val, Y_val, wgt_train=wgt_train, wgt_val=wgt_val, epochs=200, batch_size=8192*32, saveLabel='DCTR_training_no_tt_E')
with tf.device('/device:cpu:0'):
    weights_0_no_tt_E, _ = DCTR.predict_weights(dctr, X0_nrm[:,1:,:-3], X1_nrm[:,1:,:-3], batch_size=8192*16)
# Out:
# Epoch 1/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.
200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7586
# Epoch 122: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7586 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 1.1884e-04
# Epoch 123/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 123: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 1.1648e-04
# Epoch 124/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 124: val_loss improved from 0.15159 to 0.15159, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7586 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 1.1418e-04
# Epoch 125/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 125: val_loss improved from 0.15159 to 0.15159, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7583 - lr: 1.1192e-04
# Epoch 126/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 126: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 1.0970e-04
# Epoch 127/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 127: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 1.0753e-04
# Epoch 128/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 128: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 1.0540e-04
# Epoch 129/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 129: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 1.0331e-04
# Epoch 130/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 130: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 1.0127e-04
# Epoch 131/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 131: val_loss did not improve from 0.15159
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 9.9261e-05
# Epoch 132/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 132: val_loss improved from 0.15159 to 0.15158, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 9.7296e-05
# Epoch 133/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 133: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 9.5369e-05
# Epoch 134/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 134: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 9.3481e-05
# Epoch 135/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7587
# Epoch 135: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7587 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 9.1630e-05
# Epoch 136/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 136: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 8.9815e-05
# Epoch 137/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 137: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 8.8037e-05
# Epoch 138/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 138: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 8.6294e-05
# Epoch 139/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 139: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 8.4585e-05
# Epoch 140/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 140: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 8.2910e-05
# Epoch 141/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 141: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 8.1268e-05
# Epoch 142/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 142: val_loss improved from 0.15158 to 0.15158, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 7.9659e-05
# Epoch 143/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 143: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 7.8082e-05
# Epoch 144/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 144: val_loss did not improve from 0.15158
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 7.6536e-05
# Epoch 145/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 145: val_loss improved from 0.15158 to 0.15157, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 7.5020e-05
# Epoch 146/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 146: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 7.3535e-05
# Epoch 147/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 147: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 7.2079e-05
# Epoch 148/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 148: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 70ms/step - loss: 0.1514 - acc: 0.7588 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 7.0651e-05
# Epoch 149/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7588
# Epoch 149: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 6.9252e-05
# Epoch 150/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 150: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 6.7881e-05
# Epoch 151/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 151: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 6.6537e-05
# Epoch 152/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 152: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 6.5219e-05
# Epoch 153/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 153: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 6.3928e-05
# Epoch 154/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 154: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7589 - lr: 6.2662e-05
# Epoch 155/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 155: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 6.1421e-05
# Epoch 156/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 156: val_loss improved from 0.15157 to 0.15157, saving model to /tf/home/gdrive/_STUDIUM_/Semester_06/BachelorThesis/Notebooks/input_tests/DCTR_training_no_tt.h5
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 6.0205e-05
# Epoch 157/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 157: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 5.9013e-05
# Epoch 158/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 158: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 5.7844e-05
# Epoch 159/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 159: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 5.6699e-05
# Epoch 160/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 160: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7588 - lr: 5.5576e-05
# Epoch 161/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7589
# Epoch 161: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 5.4476e-05
# Epoch 162/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7590
# Epoch 162: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 5.3397e-05
# Epoch 163/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7590
# Epoch 163: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 5.2340e-05
# Epoch 164/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7590
# Epoch 164: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7588 - lr: 5.1303e-05
# Epoch 165/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7590
# Epoch 165: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1514 - acc: 0.7589 - val_loss: 0.1516 - val_acc: 0.7585 - lr: 5.0288e-05
# Epoch 166/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7590
# Epoch 166: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 4.9292e-05
# Epoch 167/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7590
# Epoch 167: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1514 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 4.8316e-05
# Epoch 168/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7590
# Epoch 168: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1513 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 4.7359e-05
# Epoch 169/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.7590
# Epoch 169: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1513 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7586 - lr: 4.6421e-05
# Epoch 170/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7590
# Epoch 170: val_loss did not improve from 0.15157
# 120/120 [==============================] - 8s 68ms/step - loss: 0.1513 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7587 - lr: 4.5502e-05
# Epoch 171/200
# 119/120 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.7590
# Epoch 171: val_loss did not improve from 0.15157
# Restoring model weights from the end of the best epoch: 156.
# 120/120 [==============================] - 8s 69ms/step - loss: 0.1513 - acc: 0.7590 - val_loss: 0.1516 - val_acc: 0.7584 - lr: 4.4601e-05
# Epoch 171: early stopping
# 226/226 [==============================] - 27s 118ms/step
# 73/73 [==============================] - 9s 117ms/step

# %%
# current weights to compare to:
dctr, callbacks = DCTR.setup_nn(input_dim=6, loss='mse')
dctr.load_weights('DCTR_training.h5')
with tf.device('/device:cpu:0'):
    weights_0, _ = DCTR.predict_weights(dctr, X0_nrm[:,:,:-2], X1_nrm[:,:,:-2], batch_size=8192*16)
# Out:
# 226/226 [==============================] - 36s 156ms/step
# 73/73 [==============================] - 11s 152ms/step

# %% [markdown]
# # load training and predict weights

# %%
wgt_args = [(weights_0, 'current: incl. tt-pair and energy'),
            (weights_0_no_tt, 'no tt-pair'),
            (weights_0_no_E, 'no E'),
            (weights_0_no_tt_E, 'no tt-pair and no energy')]

DCTR.plot_weights(wgt_args, title='weights comparison', stop = 7)

# %% [markdown]
# # check and plot DCTR predictions

# %%
def delta_phi(X):
    phi_t = X[:,1, 2] # phi of top quark
    phi_t_bar = X[:,2, 2] # phi of anti-top quark
    delta = phi_t - phi_t_bar
    # remap delta from [-2*pi, 2*pi] to [0, 2pi]
    delta = ((delta + 2*math.pi) % (2*math.pi))
    # remap to [0, pi] since it is symmetrical
    delta = math.pi - abs(delta-math.pi)
    
    return delta

X0_delta_phi = delta_phi(X0_test)
X1_delta_phi = delta_phi(X1_test)

# %%
args_phi = [(X1_delta_phi, X1_nrm_wgt, 'NNLO'),
            (X0_delta_phi, weights_0, 'current: incl. tt-pair and energy'),
            (X0_delta_phi, weights_0_no_tt, 'no tt-pair'),
            (X0_delta_phi, weights_0_no_E, 'no E'),
            (X0_delta_phi, weights_0_no_tt_E, 'no tt-pair and no energy')]

DCTR.plot_ratio(args_phi, title = r'$\Delta \Phi$', x_label = r'$\Delta \Phi$ [radian]', start = 0, stop = math.pi, div = 31)
# Out:
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and energy:
#  Mean Absolute Error 949.034375
#  chi square of 35.09405962859335 with p 0.20146776502010322
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 8683.20078125
#  chi square of 2118.241826701895 with p 0.0
#  compared to NNLO
# no E:
#  Mean Absolute Error 1669.5716145833333
#  chi square of 59.294558333931946 with p 0.0007553547782811184
#  compared to NNLO
# no tt-pair and no energy:
#  Mean Absolute Error 1118.152734375
#  chi square of 48.5033613561501 with p 0.013025330902701335
#  compared to NNLO
# ([0.0, 949.034375, 8683.20078125, 1669.5716145833333, 1118.152734375],
#  [0.0,
#   35.09405962859335,
#   2118.241826701895,
#   59.294558333931946,
#   48.5033613561501],
#  [1.0, 0.20146776502010322, 0.0, 0.0007553547782811184, 0.013025330902701335])

# %%
# DCTR.plot_ratio()
# takes args in form [(X0, wgt0, label0),(X1, wgt1, label1), etc.]
# plots histograms of X's and a ratio plot comapring all X's to X0 (first input in args)
# calculates, prints and returns mae, chi2 and p-value (from chi2 and num_bins)
# default parameters: 
    # arg_index = 0, part_index = 0, # which observable from the dataset to plot. Ignored if 1D dataset is passed (like in delta phi above)
    # title = None, x_label = None, y_label = None, # if None are given, generate title, etc. from arg/part index
    # bins = None, start = None, stop = None, div = 35, # if bins is None generate binning with start/stop if None are given use min/max
    # ratio_ylim=[0.9,1.1], figsize=(8,8), layout='rows', stats_only=False # plotting args

args = [(X1_test, X1_nrm_wgt, 'NNLO'),
        (X0_test, weights_0, 'current: incl. tt-pair and E'),
        (X0_test, weights_0_no_tt, 'no tt-pair'),
        (X0_test, weights_0_no_E, 'no E'),
        (X0_test, weights_0_no_tt_E, 'no tt-pair and no E')]

arg_indices = [0, 1, 3, 4, 5] # pt, y, eta, mass, energy
part_indices = [0, 1] # tt-pair and too

mae_all = []
chi2_all = []
p_all = []

# set plotting parameters
for part_index in part_indices:
    for arg_index in arg_indices:
        bins = []
        ratio_ylim = [0.75, 1.25]
        div = 31
        if arg_index == 1:  # rapidity
            start = None
            stop = None
        elif arg_index == 3:  # mass
            if part_index == 0:  # tt-pair
                start = None
                stop = 1500
                ratio_ylim = [0.90, 1.10]
            else:
                start = None
                stop = None
                div = 32
                ratio_ylim = [0.85, 1.15]
        elif arg_index == 4:  # pseudorapidity
            start = -9
            stop = 9
        elif arg_index == 5: # energy
            ratio_ylim = [0.9, 1.10]
            if part_index == 0:  # tt-pair
                start = None
                stop = 3000
            else:
                start = None
                stop = 2000
        else:  # pt
            ratio_ylim = [0.8, 1.2]
            start = 0
            stop = 1000
        
        # plot and calculate stats
        mae_list, chi2_list, p_list = DCTR.plot_ratio(args, arg_index=arg_index, part_index=part_index,
                                                      start=start, stop=stop, div=div, ratio_ylim=ratio_ylim)
        # save stats
        mae_all.append(mae_list)
        chi2_all.append(chi2_list)
        p_all.append(p_list)
# Out:
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 708.7488423665365
#  chi square of 25.344234571803398 with p 0.6602682922107814
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 2712.0599197387696
#  chi square of 316.48265161853294 with p 4.390039396874534e-50
#  compared to NNLO
# no E:
#  Mean Absolute Error 810.8831471761067
#  chi square of 28.269834315204758 with p 0.5035227446786776
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 1050.8460372924806
#  chi square of 37.95403179918814 with p 0.12336186552165995
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 1504.049252128601
#  chi square of 93.39276530962172 with p 1.0843489288286661e-08
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 1377.3063103993734
#  chi square of 82.3136303198113 with p 5.285002896103609e-07
#  compared to NNLO
# no E:
#  Mean Absolute Error 948.275157292684
#  chi square of 30.55236042011274 with p 0.3868248267477651
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 1443.3653419494628
#  chi square of 83.80751750075997 with p 3.167216985577434e-07
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 607.8951985677083
#  chi square of 11.340559160055804 with p 0.9986506667865398
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 1019.7830973307292
#  chi square of 101.22130070629098 with p 6.232393932070798e-10
#  compared to NNLO
# no E:
#  Mean Absolute Error 1450.6036458333333
#  chi square of 70.31006939317001 with p 2.749669628988683e-05
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 1130.0556070963542
#  chi square of 106.47560012172111 with p 8.773305689872858e-11
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 1682.7936848958334
#  chi square of 98.95750507777782 with p 1.4355117294568062e-09
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 6734.2364501953125
#  chi square of 6716.010615296556 with p 0.0
#  compared to NNLO
# no E:
#  Mean Absolute Error 1390.585819498698
#  chi square of 49.861356424232326 with p 0.009347283797357823
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 3174.5623413085937
#  chi square of 2340.814733587607 with p 0.0
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 932.2927083333333
#  chi square of 30.73916231068634 with p 0.37782301262588514
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 1941.3288411458334
#  chi square of 132.97640151612646 with p 2.9154068325334895e-15
#  compared to NNLO
# no E:
#  Mean Absolute Error 1890.0310872395833
#  chi square of 68.89986112816219 with p 4.281681444752369e-05
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 1882.6982096354166
#  chi square of 126.79934188994355 with p 3.406675883246722e-14
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 592.2015833536784
#  chi square of 17.08921057070602 with p 0.9607776382419361
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 986.4408093770345
#  chi square of 73.32618431673582 with p 1.0492244712841529e-05
#  compared to NNLO
# no E:
#  Mean Absolute Error 1059.332657623291
#  chi square of 34.02013284942724 with p 0.23852391319051908
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 946.3315299987793
#  chi square of 64.93937477919476 with p 0.0001444349520017497
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 1170.8744016965231
#  chi square of 66.8949378716975 with p 7.965867745160285e-05
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 1136.5837291876476
#  chi square of 75.33048760261298 with p 5.467480477246883e-06
#  compared to NNLO
# no E:
#  Mean Absolute Error 1371.4862033367158
#  chi square of 45.05571782956128 with p 0.029059346707610772
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 1120.4920504570007
#  chi square of 76.10833121883802 with p 4.23541681747335e-06
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 575.8291015625
#  chi square of 57.837482308863954 with p 0.0016689769904934437
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 445.46033896169354
#  chi square of 38.165112457067565 with p 0.1455561158019494
#  compared to NNLO
# no E:
#  Mean Absolute Error 574.4979838709677
#  chi square of 72.05272353813089 with p 2.5644422723646754e-05
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 471.3592489919355
#  chi square of 25.941447572413487 with p 0.6781168535460395
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 1242.057284975052
#  chi square of 38.7994887453533 with p 0.10556395204709085
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 635.6213211377461
#  chi square of 18.159582209767493 with p 0.9409555318019367
#  compared to NNLO
# no E:
#  Mean Absolute Error 901.7767575581869
#  chi square of 17.50982697464334 with p 0.9536571877835366
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 730.5782944520314
#  chi square of 21.23776131104992 with p 0.8503413949654104
#  compared to NNLO
# NNLO:
#  Mean Absolute Error 0.0
#  chi square of 0.0 with p 1.0
#  compared to NNLO
# current: incl. tt-pair and E:
#  Mean Absolute Error 728.372802734375
#  chi square of 18.787135129363463 with p 0.9266245569632585
#  compared to NNLO
# no tt-pair:
#  Mean Absolute Error 1320.1440755208334
#  chi square of 68.338904302041 with p 5.0993107476313186e-05
#  compared to NNLO
# no E:
#  Mean Absolute Error 1530.1454264322917
#  chi square of 41.200733928034815 with p 0.0661353128935078
#  compared to NNLO
# no tt-pair and no E:
#  Mean Absolute Error 1407.4684244791667
#  chi square of 69.03656641684601 with p 4.102655048837683e-05
#  compared to NNLO

# %%
# mean stats for each in args
mae_mean = np.mean(mae_all, axis = 0)
chi2_mean = np.mean(chi2_all, axis = 0)
p_mean = np.mean(p_all, axis = 0)

print('[NNLO], [current: incl. tt-pair and E], [no tt-pair], [no E], [no tt-pair and no E] \n')
print(f'MAE  mean: {mae_mean} \n')
print(f'chi2 mean: {chi2_mean} \n')
print(f'p    mean: {p_mean} \n')
# Out:
# [NNLO], [current: incl. tt-pair and E], [no tt-pair], [no E], [no tt-pair and no E]
#
# MAE  mean: [   0.          974.51148606 1830.8964893  1192.76178859 1335.77570857]
#
# chi2 mean: [  0.          45.91824811 762.23248703  45.77326168 295.31147062]
#
# p    mean: [1.         0.40314568 0.10865791 0.21871666 0.16520101]
